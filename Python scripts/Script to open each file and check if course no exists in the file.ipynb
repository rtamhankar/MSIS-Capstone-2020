# %%
import os 
# This is to get the directory that the program  
# is currently running in. 
dir_path = os.path.dirname(os.path.realpath("C:\\Users\\Nachiket\\Desktop\\Capstone\\Syllabi\\")) 
##print(dir_path)
filepdf = []
rootpdf = []
filedoc = []
rootdoc = []
filedocx = []
rootdocx = []
path = []
  
for root, dirs, files in os.walk(dir_path): 
    for file in files:  
  
        # change the extension from '.mp3' to  
        # the one of your choice. 
        if file.endswith('.pdf'):
            #print (root+'/'+str(file))
            a = root+'/'+str(file)
            filepdf.append(file)
            rootpdf.append(a)
            ##print(a)
        
        elif file.endswith('.doc'):
            #print (root+'/'+str(file))
            b = root+'/'+str(file)
            filedoc.append(file)
            rootdoc.append(b)
        
        else: 
            #print (root+'/'+str(file))
            c = root+'/'+str(file)
            filedocx.append(file)
            rootdocx.append(c)

# %%
import pandas as pd

# %%
rootpdf
# Out:
# ['C:\\Users\\Nachiket\\Desktop\\Capstone\\Syllabi\\2017-18\\Fall 2017/Fall 2017 2603 - Fall 2017 Syllabus (1).pdf',
#  'C:\\Users\\Nachiket\\Desktop\\Capstone\\Syllabi\\2017-18\\Fall 2017/Fall 2017 2603 - Fall 2017 Syllabus.pdf',
#  'C:\\Users\\Nachiket\\Desktop\\Capstone\\Syllabi\\2017-18\\Fall 2017/Fall 2017 MBA 3250Syllabus.pdf',
#  'C:\\Users\\Nachiket\\Desktop\\Capstone\\Syllabi\\2017-18\\Fall 2017/Fall 2017 MSIS 2627.pdf',
#  'C:\\Users\\Nachiket\\Desktop\\Capstone\\Syllabi\\2017-18\\Fall 2017/Fall 2017 msis 2629 fall2017.pdf',
#  'C:\\Users\\Nachiket\\Desktop\\Capstone\\Syllabi\\2017-18\\Fall 2017/Fall 2017 MSIS2624-Syllabus-2017Fall-pdf (1).pdf',
#  'C:\\Users\\Nachiket\\Desktop\\Capstone\\Syllabi\\2017-18\\Fall 2017/Fall 2017 MSIS2624-Syllabus-2017Fall-pdf.pdf',
#  'C:\\Users\\Nachiket\\Desktop\\Capstone\\Syllabi\\2017-18\\Fall 2017/Fall 2017 MSIS2641_Fall2017_Syllabus-Seidler (1).pdf',
# ...

# %%
rootdoc
# Out:
# ['C:\\Users\\Nachiket\\Desktop\\Capstone\\Syllabi\\2017-18\\Fall 2017/Fall 2017 OMIS 41 syllabus Fall 2017A.doc',
#  'C:\\Users\\Nachiket\\Desktop\\Capstone\\Syllabi\\2017-18\\Fall 2017/Fall 2017 OMIS 41_3_Statistics Data Analysis II_Fall 2017_syllabus    9_18_2017.doc',
#  'C:\\Users\\Nachiket\\Desktop\\Capstone\\Syllabi\\2017-18\\Fall 2017/Fall 2017 OMIS 41_4_Statistics Data Analysis II_Fall 2017_syllabus    9_18_2017.doc',
#  'C:\\Users\\Nachiket\\Desktop\\Capstone\\Syllabi\\2017-18\\Spring 2018/Spring 2018 OMIS 3200 SCU Quantitative Methods_5 weeks_OMIS 3200_MW Spring 2018_Syllabus   5_1_2018.doc',
#  'C:\\Users\\Nachiket\\Desktop\\Capstone\\Syllabi\\2017-18\\Spring 2018/Spring 2018 OMIS 40-3  Syllabus_Statistics _ Data Analysis I_TTH 830_Syllabus_Spring 2018.doc',
#  'C:\\Users\\Nachiket\\Desktop\\Capstone\\Syllabi\\2017-18\\Spring 2018/Spring 2018 OMIS 40-4  Syllabus_Statistics _ Data Analysis I_TTH 1210_Syllabus_Spring 2018.doc',
# ...

# %%
rootdocx
# Out:
# ['C:\\Users\\Nachiket\\Desktop\\Capstone\\Syllabi\\2017-18\\Fall 2017/Fall 2017 40 Syllabus Fall 2017.docx',
#  'C:\\Users\\Nachiket\\Desktop\\Capstone\\Syllabi\\2017-18\\Fall 2017/Fall 2017 MSIS 2602 syllabus_Fall 2017.docx',
#  'C:\\Users\\Nachiket\\Desktop\\Capstone\\Syllabi\\2017-18\\Fall 2017/Fall 2017 MSIS2604 Syllabus -- Fall 2017.docx',
#  'C:\\Users\\Nachiket\\Desktop\\Capstone\\Syllabi\\2017-18\\Winter 2018/Winter 2018 2603 - Winter 2018 Syllabus.docx',
#  'C:\\Users\\Nachiket\\Desktop\\Capstone\\Syllabi\\2017-18\\Winter 2018/Winter 2018 63945-MSIS2802-68943-IDIS3802-syllabus-Winter2018.docx',
#  'C:\\Users\\Nachiket\\Desktop\\Capstone\\Syllabi\\2017-18\\Winter 2018/Winter 2018 63946-MSIS2802-68943-IDIS3802-syllabus-Winter2018.docx',
#  'C:\\Users\\Nachiket\\Desktop\\Capstone\\Syllabi\\2017-18\\Winter 2018/Winter 2018 Escobar_OMIS 015_W18_R_Syllabus.docx',
# ...

# %% [markdown]
# **Write a function to check if the parameter exists in the path, if yes, return the path**

# %%
#def calcpath(param):
#    arr =[]
#    val = param
#    for root in rootpdf:
#        if val in root :
#            arr.append(root)
#    for root in rootdoc:
#        if val in root :
#            arr.append(root)
#    for root in rootdocx:
#        if val in root :
#            arr.append(root)
#    return arr

# %%
import PyPDF2 
import textract
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# %%
from PyPDF2 import PdfFileWriter, PdfFileReader
from nltk.tokenize import sent_tokenize
def checkcrs(param, dep):
    arr = []
    val = str(param)
    dep = dep
    comb = dep+param
    for root in rootpdf:
        pdfFileObj = open(root, 'rb')
        #The pdfReader variable is a readable object that will be parsed.
        pdfReader = PyPDF2.PdfFileReader(pdfFileObj)
        #Discerning the number of pages will allow us to parse through all the pages.
        #num_pages = pdfReader.numPages
        num_pages = 1
        count = 0
        pdftext = ""
        #The while loop will read each page.
        while count < num_pages:
            pageObj = pdfReader.getPage(count)
            count +=1
            pdftext += pageObj.extractText()
        wordspdf = word_tokenize(pdftext)
        #wordspdf = pdftext.split()
        #print(wordspdf)
        if val in wordspdf:
            if dep in wordspdf:
                arr.append(root)
        elif comb in wordspdf:
            arr.append(root)
    return arr

# %%
dfcourse = pd.read_excel('Course Table.xls')

# %%
dfcourse.head()
# Out:
#    Course ID Subject Catalog                          Descr Status   Eff Date  \
# 0      63018    ACTG     300           Financial Accounting      A 2008-01-24
# 1      50122    ACTG     301    Actg for Business Decisions      A 1999-10-12
# 2      63045    ACTG     302          Managerial Accounting      A 2009-10-08
# 3      10049    ACTG     303  Corporate Financial Reporting      A 2009-10-08
# 4      60566    ACTG     303  Corporate Financial Reporting      A 2007-12-10
#
#   Consent Grading  Min Units  Max Units Repeatable  Allowd Unt  Allow Comp  \
# 0       N     GRD          3          3          N           3           1
# 1       N     GRD          3          3          N           3           1
# 2       N     GRD          3          3          N           3           1
# 3       N     GRD          3          3          N           3           1
# 4       N     GRD          3          3          N           3           1
#
# ...

# %%
arrcourse = checkcrs('2601', 'MSIS')

# %%
arrcourse
# Out:
# ['C:\\Users\\Nachiket\\Desktop\\Capstone\\Syllabi\\2017-18\\Summer 2018/MSIS2601-Outline.pdf']

# %%
arr3200 = checkcrs('3200','OMIS')

# %%
arr3200
# Out:
# ['C:\\Users\\Nachiket\\Desktop\\Capstone\\Syllabi\\2017-18\\Fall 2017/Fall 2017 OMIS 3200 - FA 17 - WARREN.pdf',
#  'C:\\Users\\Nachiket\\Desktop\\Capstone\\Syllabi\\2017-18\\Fall 2017/Fall 2017 OMIS 3200 - FA 17B - WARREN.pdf',
#  'C:\\Users\\Nachiket\\Desktop\\Capstone\\Syllabi\\2019-2020\\Fall 2019/OMIS3200-92357-FA19-WARREN.pdf',
#  'C:\\Users\\Nachiket\\Desktop\\Capstone\\Syllabi\\2019-2020\\Fall 2019/OMIS3200-92358-FA19-WARREN.pdf']

# %%
arr2355 = checkcrs('2355', 'OMIS')

# %%
arr2355
# Out:
# ['C:\\Users\\Nachiket\\Desktop\\Capstone\\Syllabi\\2017-18\\Fall 2017/Fall 2017 OMIS 2355-2017Fall.pdf',
#  'C:\\Users\\Nachiket\\Desktop\\Capstone\\Syllabi\\2017-18\\Fall 2017/Fall 2017 OMIS2355-2017Fall.pdf',
#  'C:\\Users\\Nachiket\\Desktop\\Capstone\\Syllabi\\2018-19\\Fall 2018/Syllabus OMIS 2355 -2.pdf']

# %% [markdown]
# **Doesn't capture scanned pdfs**

# %%
arr2392 = checkcrs('2392', 'OMIS')

# %%
arr2392
# Out:
# []

# %% [markdown]
# **Doesn't capture scanned pdfs**

# %%
arr2627 = checkcrs ('2627', 'MSIS')

# %%
arr2627
# Out:
# []

# %%
#dfcourse['check'] = dfcourse['Catalog'].apply(checkcrs)

# %% [markdown]
# **Prereq ('3000') mentioned on the first page of the syllabus hence, syllabus for 3250 also got captured**

# %%
arr3000 = checkcrs ('3000', 'OMIS')

# %%
arr3000
# Out:
# ['C:\\Users\\Nachiket\\Desktop\\Capstone\\Syllabi\\2017-18\\Winter 2018/Winter 2018 Syllabus OMIS3000.pdf',
#  'C:\\Users\\Nachiket\\Desktop\\Capstone\\Syllabi\\2018-19\\Fall 2018/1Course Syllabus OMIS3000.pdf',
#  'C:\\Users\\Nachiket\\Desktop\\Capstone\\Syllabi\\2018-19\\Fall 2018/2018 Fall OMIS3250 Syllabus 2018.08.30.pdf']

# %% [markdown]
# **Some of the syllabi have MSIS2641 without a space between department and course number. Both types are captured**

# %%
arr2641 = checkcrs ('2641', 'MSIS')

# %%
arr2641
# Out:
# ['C:\\Users\\Nachiket\\Desktop\\Capstone\\Syllabi\\2017-18\\Fall 2017/Fall 2017 MSIS2641_Fall2017_Syllabus-Seidler (1).pdf',
#  'C:\\Users\\Nachiket\\Desktop\\Capstone\\Syllabi\\2017-18\\Fall 2017/Fall 2017 MSIS2641_Fall2017_Syllabus-Seidler.pdf',
#  'C:\\Users\\Nachiket\\Desktop\\Capstone\\Syllabi\\2017-18\\Spring 2018/Spring 2018 MSIS2641_Spring_2018_Syllabus-Seidler.pdf',
#  'C:\\Users\\Nachiket\\Desktop\\Capstone\\Syllabi\\2017-18\\Winter 2018/Winter 2018 MSIS2641_Winter2018_Syllabus-Seidler.pdf',
#  'C:\\Users\\Nachiket\\Desktop\\Capstone\\Syllabi\\2019-2020\\Fall 2019/MSIS 2641 Seidler.pdf']

# %%
dfcourse['path'] = dfcourse.apply(checkcrs,Catalog,Subject)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-148-eab0d8a4b2db> in <module>
# ----> 1 dfcourse['path'] = dfcourse.apply(checkcrs,Catalog,Subject)
#
# NameError: name 'Catalog' is not defined

# %% [markdown]
# **Overall Observations**
# 1. I am not sure if it can capture scanned pdfs. For the courses tested till now, they are not captured
# 2. Considered only 1st and 2nd page, but if prereqs are there on either of the pages they are also captured
# 3. Somehow not working properly on OMIS 3000. Need help figuring out why

# %% [markdown]
# **Extract information from the word files**

# %% [markdown]
# **Approach1** - Cancelled

# %%
#specific to extracting information from word documents
import os
import zipfile
#other tools useful in extracting the information from our document
import re
#to pretty print our xml:
import xml.dom.minidom

# %%
#os.listdir('.')

# %%
document = zipfile.ZipFile('C:\\Users\\Nachiket\\Desktop\\Capstone\\syllabi\\2017-18\\Fall 2017\\Fall 2017 MSIS2604 Syllabus -- Fall 2017.docx')
#document will be the filetype zipfile.ZipFile

# %%
document
# Out:
# <zipfile.ZipFile filename='C:\\Users\\Nachiket\\Desktop\\Capstone\\syllabi\\2017-18\\Fall 2017\\Fall 2017 MSIS2604 Syllabus -- Fall 2017.docx' mode='r'>

# %%
document.namelist()
# Out:
# ['[Content_Types].xml',
#  '_rels/.rels',
#  'word/_rels/document.xml.rels',
#  'word/document.xml',
#  'word/endnotes.xml',
#  'word/footnotes.xml',
#  'word/footer1.xml',
#  'word/footer2.xml',
#  'word/theme/theme1.xml',
#  'word/settings.xml',
#  'word/styles.xml',
#  'word/numbering.xml',
#  'docProps/app.xml',
#  'customXml/_rels/item1.xml.rels',
#  'customXml/itemProps1.xml',
#  'customXml/item1.xml',
#  'word/fontTable.xml',
#  'word/webSettings.xml',
#  'word/stylesWithEffects.xml',
#  'docProps/core.xml']

# %%
#name = 'word/people.xml'
#we can see who the document author is: Stephen C. Phillips
uglyXml = xml.dom.minidom.parseString(document.read('word/document.xml')).toprettyxml(indent='  ')

text_re = re.compile('>\n\s+([^<>\s].*?)\n\s+</', re.DOTALL)    
prettyXml = text_re.sub('>\g<1></', uglyXml)

print(prettyXml)
# Out:
# <?xml version="1.0" ?>
# ...

# %%
#name = 'word/fontTable.xml'
#This looks like the fonts used in the document style
uglyXml = xml.dom.minidom.parseString(document.read('word/fontTable.xml')).toprettyxml(indent='  ')

text_re = re.compile('>\n\s+([^<>\s].*?)\n\s+</', re.DOTALL)    
prettyXml = text_re.sub('>\g<1></', uglyXml)

print(prettyXml)
# Out:
# <?xml version="1.0" ?>
# <w:fonts mc:Ignorable="w14" xmlns:mc="http://schemas.openxmlformats.org/markup-compatibility/2006" xmlns:r="http://schemas.openxmlformats.org/officeDocument/2006/relationships" xmlns:w="http://schemas.openxmlformats.org/wordprocessingml/2006/main" xmlns:w14="http://schemas.microsoft.com/office/word/2010/wordml">
#   <w:font w:name="Symbol">
#     <w:panose1 w:val="05050102010706020507"/>
#     <w:charset w:val="02"/>
#     <w:family w:val="roman"/>
#     <w:pitch w:val="variable"/>
#     <w:sig w:csb0="80000000" w:csb1="00000000" w:usb0="00000000" w:usb1="10000000" w:usb2="00000000" w:usb3="00000000"/>
#   </w:font>
#   <w:font w:name="Times New Roman">
#     <w:panose1 w:val="02020603050405020304"/>
#     <w:charset w:val="00"/>
#     <w:family w:val="roman"/>
#     <w:pitch w:val="variable"/>
#     <w:sig w:csb0="000001FF" w:csb1="00000000" w:usb0="E0002AFF" w:usb1="C0007841" w:usb2="00000009" w:usb3="00000000"/>
#   </w:font>
# ...

# %%
xml_content = document.read('word/document.xml')
document.close()
xml_str = str(xml_content)

# %%
xml_str
# Out:
# 'b\'<?xml version="1.0" encoding="UTF-8" standalone="yes"?>\\r\\n<w:document xmlns:wpc="http://schemas.microsoft.com/office/word/2010/wordprocessingCanvas" xmlns:mc="http://schemas.openxmlformats.org/markup-compatibility/2006" xmlns:o="urn:schemas-microsoft-com:office:office" xmlns:r="http://schemas.openxmlformats.org/officeDocument/2006/relationships" xmlns:m="http://schemas.openxmlformats.org/officeDocument/2006/math" xmlns:v="urn:schemas-microsoft-com:vml" xmlns:wp14="http://schemas.microsoft.com/office/word/2010/wordprocessingDrawing" xmlns:wp="http://schemas.openxmlformats.org/drawingml/2006/wordprocessingDrawing" xmlns:w10="urn:schemas-microsoft-com:office:word" xmlns:w="http://schemas.openxmlformats.org/wordprocessingml/2006/main" xmlns:w14="http://schemas.microsoft.com/office/word/2010/wordml" xmlns:wpg="http://schemas.microsoft.com/office/word/2010/wordprocessingGroup" xmlns:wpi="http://schemas.microsoft.com/office/word/2010/wordprocessingInk" xmlns:wne="http://schemas.micro
# ...

# %%
val = "MSIS2604-01"
flag = False
lst = xml_str.split()
if val in lst:
    flag = True

# %%
lst
# Out:
# ["b'<?xml",
#  'version="1.0"',
#  'encoding="UTF-8"',
#  'standalone="yes"?>\\r\\n<w:document',
#  'xmlns:wpc="http://schemas.microsoft.com/office/word/2010/wordprocessingCanvas"',
#  'xmlns:mc="http://schemas.openxmlformats.org/markup-compatibility/2006"',
#  'xmlns:o="urn:schemas-microsoft-com:office:office"',
#  'xmlns:r="http://schemas.openxmlformats.org/officeDocument/2006/relationships"',
#  'xmlns:m="http://schemas.openxmlformats.org/officeDocument/2006/math"',
#  'xmlns:v="urn:schemas-microsoft-com:vml"',
#  'xmlns:wp14="http://schemas.microsoft.com/office/word/2010/wordprocessingDrawing"',
#  'xmlns:wp="http://schemas.openxmlformats.org/drawingml/2006/wordprocessingDrawing"',
#  'xmlns:w10="urn:schemas-microsoft-com:office:word"',
#  'xmlns:w="http://schemas.openxmlformats.org/wordprocessingml/2006/main"',
#  'xmlns:w14="http://schemas.microsoft.com/office/word/2010/wordml"',
#  'xmlns:wpg="http://schemas.microsoft.com/office/word/2010/wordprocessingGroup"',
# ...

# %%
flag
# Out:
# False

# %%
link_list = re.findall('MSIS2604-01',xml_str)[1:]
#ink_list = [x[:-1] for x in link_list]

# %%
link_list
# Out:
# []

# %% [markdown]
# **Approach2** - Cancelled

# %%
>>> import zipfile
>>> z = zipfile.ZipFile('C:\\Users\\Nachiket\\Desktop\\Capstone\\syllabi\\2017-18\\Fall 2017\\Fall 2017 MSIS2604 Syllabus -- Fall 2017.docx')
>>> "MSIS2604" in z.read("word/document.xml")

>>> z.close()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-198-48631e12f6b0> in <module>
#       1 import zipfile
#       2 z = zipfile.ZipFile('C:\\Users\\Nachiket\\Desktop\\Capstone\\syllabi\\2017-18\\Fall 2017\\Fall 2017 MSIS2604 Syllabus -- Fall 2017.docx')
# ----> 3 "MSIS2604" in z.read("word/document.xml")
#       4
#       5 z.close()
#
# TypeError: a bytes-like object is required, not 'str'

# %% [markdown]
# **Approach3** - Cancelled

# %%
from docx import *

# %%
# Open the .docx file
document = opendocx('C:\\Users\\Nachiket\\Desktop\\Capstone\\syllabi\\2017-18\\Fall 2017\\Fall 2017 MSIS2604 Syllabus -- Fall 2017.docx')

# Search returns true if found    
search(document,'MSIS2604-01')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-204-6b5fa94eb0ab> in <module>
#       2
#       3 # Open the .docx file
# ----> 4 document = opendocx('C:\\Users\\Nachiket\\Desktop\\Capstone\\syllabi\\2017-18\\Fall 2017\\Fall 2017 MSIS2604 Syllabus -- Fall 2017.docx')
#       5
#       6 # Search returns true if found
#
# NameError: name 'opendocx' is not defined

# %% [markdown]
# **Approach4** - Working

# %%
import docx2txt
 
# read in word file
result = docx2txt.process("C:\\Users\\Nachiket\\Desktop\\Capstone\\syllabi\\2017-18\\Fall 2017\\Fall 2017 MSIS2604 Syllabus -- Fall 2017.docx")

# %%
result
# Out:
# "MSIS2604-01\n\nInformation Systems Policy & Strategy\n\nFall Quarter, 2017\n\n\n\nInstructor:\tDr. Darrel A. (Del) Mank\t\t\tdmank@scu.edu\t\t\t\t\t\t\t\t\n\n\t\tCell Phone: 408-605-3983\t\t\tOffice Hours:\tBy appointment\n\n\t\tOffice:\tRoom 321W Lucas Hall \t\tClass Days:\tTTh\t\t\n\nClass Period:\t7:35pm—8:50pm  \t\tClass Room:\tLucas Hall 306\n\n\t\n\nText:  Schilling, Melissa A.; STRATEGIC MANAGEMENT of TECHNOLOGICAL INNOVATION, McGraw-Hill/Irwin,\n\n           5th Edition, 2017           ISBN 978-1-259-53906-0\n\n\n\nCases*\t\tHewlett-Packard Merced Division [HBR]\n\n\t\tSAP AG in 2006 [Stanford]\n\n\t\tVMware Inc., 2008 [HBR]\n\n\t\tSkype vs AT&T [University of Alabama]\n\n\t\tOracle vs. salesforce.com [HBR]\n\n\t\tNetflix in 2012 [University of Alabama]\n\n\t\tGoogle Strategy in 2012 [University of South Alabama]\n\n\n\n\t\t*All Cases are available at the SCU Bookstore\n\n\n\nCourse Objectives: \n\nIdentify the range, scope, and complexity of the issues and problems related 
# ...

# %%
val = "MSIS2604"
flag = False
lst = xml_str.split()
if val in result:
    flag = True

# %%
flag
# Out:
# True

# %%
def checkcrsdocx(param,dep):
    arr = []
    val = str(param)
    dep = dep
    comb = dep+param
    for root in rootdocx:
        result = docx2txt.process(root)
        if val in result:
            if dep in result:
                arr.append(root)
        elif comb in result:
            arr.append(root)
    return arr

# %%
arr2604 = checkcrsdocx('2604','MSIS')
# Out:
# ---------------------------------------------------------------------------
# BadZipFile                                Traceback (most recent call last)
# <ipython-input-221-c6d2389aaaac> in <module>
# ----> 1 arr2604 = checkcrsdocx('2604','MSIS')
#
# <ipython-input-220-e1bcb1339502> in checkcrsdocx(param, dep)
#       5     comb = dep+param
#       6     for root in rootdocx:
# ----> 7         result = docx2txt.process(root)
#       8         if val in result:
#       9             if dep in result:
#
# ~\Anaconda3\lib\site-packages\docx2txt\docx2txt.py in process(docx, img_dir)
#      74
#      75     # unzip the docx in memory
# ---> 76     zipf = zipfile.ZipFile(docx)
#      77     filelist = zipf.namelist()
#      78
#
# ~\Anaconda3\lib\zipfile.py in __init__(self, file, mode, compression, allowZip64)
#    1129         try:
#    1130             if mode == 'r':
# -> 1131                 self._RealGetContents()
#    1132             elif mode in ('w', 'x'):
# ...
